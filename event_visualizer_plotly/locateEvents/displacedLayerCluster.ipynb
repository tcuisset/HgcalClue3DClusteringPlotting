# %%
# %load_ext autoreload
# %autoreload 2
import math
from functools import partial
import uproot
import numpy as np
import pandas as pd
import awkward as ak
from tqdm import tqdm

import sys
sys.path.append("../..")
from hists.parameters import thresholdW0 as defaultThresholdW0
from hists.parameters import synchrotronBeamEnergiesMap
from hists.dataframe import DataframeComputations
from utils import makeDashLink, makeCsvRow, printCsvRowsFromDf

from event_visualizer_plotly.vis_layer import LayerVisualization
from event_visualizer_plotly.vis_clue3D import Clue3DVisualization
from event_visualizer_plotly.utils import EventLoader, EventID, LoadedEvent
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
input_file = '/data_cms_upgrade/cuisset/testbeam18/clue3d/v31/cmssw/data/CLUE_clusters.root'
tree = uproot.open(input_file + ":clusters")
eventLoader = EventLoader(input_file)

# %%
clus2D_columns = ["beamEnergy", "clus2D_x", "clus2D_y", "clus2D_layer", "clus2D_energy", "clus2D_size"]

# %%
array = tree.arrays(entry_stop=1000)
comp_test = DataframeComputations(array)  #.set_index(["event", "clus3D_id", "clus2D_id"])

# %%
def makeBarycenterDf(comp:DataframeComputations, thresholdW0=defaultThresholdW0):
    return comp.computeBarycenter(
        (comp.clusters2D_merged_rechits(frozenset(["rechits_x", "rechits_y", "rechits_energy", "rechits_layer"]), useCachedRechits=False,
            clusters2D_columns=[])
         .set_index(["rechits_id"], append=True)), 
        groupbyColumns=["eventInternal","clus2D_id"], thresholdW0=thresholdW0
    )

# %%
def barycenterDifferenceFromDefault(comp:DataframeComputations):
    df_barycenter_noDistance = makeBarycenterDf(comp)
    return (comp.clusters2D_custom(clus2D_columns)
        .assign(clus2D_x_barycenter=df_barycenter_noDistance.rechits_x_barycenter,
            clus2D_y_barycenter=df_barycenter_noDistance.rechits_y_barycenter)
        .eval(
            "clus2D_distance_positionToBarycenter = "
            " sqrt((clus2D_x - clus2D_x_barycenter)**2 + (clus2D_y - clus2D_y_barycenter)**2)"
        )
    )

# %%
def lookupLargeDistancePositionBarycenter(df:pd.DataFrame, _:DataframeComputations, minDistance=3):
    return (df
        .query("clus2D_distance_positionToBarycenter >= @minDistance")
        [clus2D_columns+["clus2D_x_barycenter", "clus2D_y_barycenter"]]
    )
            

def lookupLargeDistanceToImpactNotInBarycenter(barycenterDistance_df:pd.DataFrame, comp:DataframeComputations,
        minDistancePositionToBarycenter=2, maxDistanceBarycenterToImpact=1, minDistancePositionToImpact=1, beamEnergyFraction=0.2/28):
    return (
        pd.merge(barycenterDistance_df, comp.impact, how="left", 
                 left_on=["eventInternal", "clus2D_layer"],
                 right_on=["eventInternal", "layer"])
        .eval(
            "clus2D_distance_positionToImpact = "
            " sqrt((clus2D_x - impactX)**2 + (clus2D_y - impactY)**2)"
            "\n"
            "clus2D_distance_barycenterToImpact = "
            " sqrt((clus2D_x_barycenter - impactX)**2 + (clus2D_y_barycenter - impactY)**2)"
        )
        .query("clus2D_distance_positionToBarycenter >=2 and clus2D_distance_barycenterToImpact<1 and clus2D_distance_positionToImpact>1"
               " and clus2D_energy >= @beamEnergyFraction * beamEnergy")
    )

# %%
def findDisplacedLC(lookupFunctions:list, maxCount=math.inf):
    """ Find displaced LC
    Parameters : 
     - lookupFunctions : a list of functions, taking as argument : 
            barycenterDistance_df (output of barycenterDifferenceFromDefault), comp (current DataframeComputations)
     - maxCount : stop early after finding this event count
    """
    filtered_df = {fct.__name__ : [] for fct in lookupFunctions}
    counts = {fct.__name__ : 0 for fct in lookupFunctions}
    count = 0
    with tqdm(total=tree.num_entries) as pbar:
        for array, report in tree.iterate(step_size="50MB", library="ak", report=True,
                filter_name=["event", "ntupleNumber", "beamEnergy", "rechits_x", "rechits_y", "rechits_layer", "rechits_energy", "clus2D_idxs"]
                    +clus2D_columns+["impactX", "impactY"]):
            pbar.update(report.stop-report.start)
            comp = DataframeComputations(array)
            barycenterDistance_df = barycenterDifferenceFromDefault(comp)

            for lookupFct in lookupFunctions:
                out_df = lookupFct(barycenterDistance_df, comp).join(comp.ntupleEvent, rsuffix="_r")
                filtered_df[lookupFct.__name__].append(out_df)
                count += out_df.size
            
            if max(counts.values()) >= maxCount:
                break

    return {fctName : pd.concat(dfList) for fctName, dfList in filtered_df.items()}

# %%
new_res = findDisplacedLC([lookupLargeDistanceToImpactNotInBarycenter], maxCount=10)
# Out:
# 100%|██████████| 281873/281873 [05:27<00:00, 861.59it/s]

# %%
new_res["lookupLargeDistanceToImpactNotInBarycenter"]
# Out:
#                beamEnergy  clus2D_x  clus2D_y  clus2D_layer  clus2D_energy
# eventInternal
# 2188                300.0  0.132431 -2.627239            21       4.489776  \
# 4227                 20.0 -0.115370 -2.639524            11       1.307235
# 4261                 20.0  0.993857 -0.982170            11       0.611015
# 4482                 20.0  3.808441 -2.643109            13       0.370139
# 4847                 20.0  0.092501 -1.462216            26       0.728091
# ...                   ...       ...       ...           ...            ...
# 224                 200.0  2.530216  1.545875            17       3.769590
# 1325                200.0  1.037730  1.363288            19       3.046685
# 1928                200.0  0.041231  1.894837            17       2.893883
# 2676                200.0  3.917991 -1.409016            19       2.725332
# 2886                200.0 -0.841691 -0.939486            21       2.870970
#
#                clus2D_size  clus2D_x_barycenter  clus2D_y_barycenter
# eventInternal
# 2188                    44             2.160665            -1.562583  \
# 4227                    12             1.740425            -1.680209
# 4261                    13             2.683137            -2.342316
# 4482                     8             1.983435            -1.818355
# 4847                    13             2.055274            -1.950290
# ...                    ...                  ...                  ...
# 224                     45             2.200747            -0.496785
# 1325                    40             1.756938            -0.738686
# 1928                    32             1.782135             0.045749
# 2676                    41             1.780729            -0.684871
# 2886                    37             1.199725            -0.597335
#
#                clus2D_distance_positionToBarycenter   impactX   impactY
# eventInternal
# 2188                                       2.290682  2.729243 -1.844479  \
# 4227                                       2.089081  2.502419 -1.173682
# 4261                                       2.168794  3.407568 -1.979674
# 4482                                       2.002715  1.873408 -1.766203
# 4847                                       2.022547  2.687501 -1.806524
# ...                                             ...       ...       ...
# 224                                        2.069060  1.825171 -0.737863
# 1325                                       2.221611  1.931021 -1.192247
# 1928                                       2.539660  2.454605 -0.147047
# 2676                                       2.256607  1.792248 -1.177429
# 2886                                       2.069890  1.891385 -1.078122
#
#                clus2D_distance_positionToImpact
# eventInternal
# 2188                                   2.712222  \
# 4227                                   3.000252
# 4261                                   2.611708
# 4482                                   2.124457
# 4847                                   2.617742
# ...                                         ...
# 224                                    2.390093
# 1325                                   2.707162
# 1928                                   3.161275
# 2676                                   2.138321
# 2886                                   2.736590
#
#                clus2D_distance_barycenterToImpact  ntupleNumber  event
# eventInternal
# 2188                                     0.634623           435   9732  \
# 4227                                     0.914989           436    947
# 4261                                     0.810130           436   1104
# 4482                                     0.121761           436   2428
# 4847                                     0.648367           437   7039
# ...                                           ...           ...    ...
# 224                                      0.446291           675   8634
# 1325                                     0.485821           675    630
# 1928                                     0.699561           676   3502
# 2676                                     0.492692           676   4830
# 2886                                     0.842348           676   9953
#
#                beamEnergy_r
# eventInternal
# 2188                  300.0
# 4227                   20.0
# 4261                   20.0
# 4482                   20.0
# 4847                   20.0
# ...                     ...
# 224                   200.0
# 1325                  200.0
# 1928                  200.0
# 2676                  200.0
# 2886                  200.0
#
# [1720 rows x 16 columns]

# %%
full_result_df=findDisplacedLC()
# Out:
# 100%|██████████| 281873/281873 [05:34<00:00, 843.92it/s]

# %%
full_result_df
# Out:
#                          clus2D_x  clus2D_y  clus2D_layer  clus2D_energy
# eventInternal clus2D_id
# 739           49         8.243876 -5.758401            23       0.084619  \
# 1968          78         4.974807  0.327768            28       0.054176
# 3095          80         2.051345 -4.735708            27       0.815949
# 3954          57        -1.865650 -1.468376            23       0.942199
# 1388          24         5.888155 -1.480896            17       0.407511
# ...                           ...       ...           ...            ...
# 3959          60         2.032055 -3.718864            24       0.766660
# 4972          53         4.950828 -3.091922            23       0.943172
# 5084          59         0.102371 -3.610464            27       0.523415
# 6413          44         9.785860 -1.480896            17       0.054240
# 7188          54         5.949295 -2.485229            28       0.062295
#
#                          clus2D_size  clus2D_x_barycenter
# eventInternal clus2D_id
# 739           49                   8             8.572225  \
# 1968          78                   6             2.512180
# 3095          80                  18             2.643105
# 3954          57                  25             1.372259
# 1388          24                  14             2.920358
# ...                              ...                  ...
# 3959          60                  20             3.291785
# 4972          53                  18             2.159730
# 5084          59                  14             3.029785
# 6413          44                   5             7.465124
# 7188          54                   8             3.271466
#
#                          clus2D_y_barycenter  ntupleNumber  event  beamEnergy
# eventInternal clus2D_id
# 739           49                   -2.762731           435   2243       300.0
# 1968          78                   -1.490072           435   4627       300.0
# 3095          80                   -1.594443           435   8652       300.0
# 3954          57                   -1.308590           435    479       300.0
# 1388          24                   -1.019571           442   1630        20.0
# ...                                      ...           ...    ...         ...
# 3959          60                   -0.865427           675   8183       200.0
# 4972          53                   -1.631163           675   4286       200.0
# 5084          59                   -2.245699           675   1043       200.0
# 6413          44                    0.744616           676   7398       200.0
# 7188          54                   -0.830543           676    397       200.0
#
# [124 rows x 10 columns]

# %%
full_result_df.event.iloc[3]
# Out:
# 479

# %%
def loadEventFromDf(df, index) -> tuple[LoadedEvent, int]:
    """ Returns LoadedEvent, layerNb tuple """
    return eventLoader.loadEvent(EventID(df.ntupleNumber.iloc[index], df.event.iloc[index])), df.clus2D_layer.iloc[index]
def plotEventLayer(event, layer):
    vis_layer = (LayerVisualization(event, layerNb=layer) 
        .add2DClusters()
        .addRechits()
        .addImpactPoint()
        .addCircleSearchForComputingClusterPosition()
        #.addDetectorExtent()
        )
    vis_layer.fig.show()
def plotEvent3D(event, _):
    vis_3d = (Clue3DVisualization(event)
        .add3DClusters()
        .add2DClusters()
        .addRechits()
        .addImpactTrajectory()
        .addDetectorCylinder()
        .addSliders()
    )
    vis_3d.fig.show()

# %%
eventLayer = loadEventFromDf(full_result_df, 2)

# %%
plotEventFromDf(*eventLayer)
# Out:
# <div>                            <div id="3ef4864b-c7c4-4239-a263-0a0e1dcdab09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ef4864b-c7c4-4239-a263-0a0e1dcdab09")) {                    Plotly.newPlot(                        "3ef4864b-c7c4-4239-a263-0a0e1dcdab09",                        [{"customdata":[[0.8159489631652832,0.841799259185791,3.5271921157836914,"Seed"]],"hovertemplate":"2D cluster : %{customdata[3]}<br>Energy: %{customdata[0]:.2g} GeV<br>Rho: %{customdata[1]:.2g} GeV<br>Delta: %{customdata[2]:.2g} cm<br>Size: %{marker.size}","legendgroup":"cluster2D","legendgrouptitle":{"text":"2D clusters"},"marker":{"color":["#AB63FA"],"line":{"color":"#EF553B","width":3.0},"size":[18],"symbol":"circle"},"mode":"markers","name":"Trackster nb 1.0","x":[2.051345109939575],"y":[-4.735708236694336],"type":"scatter"},{"customdata":[["0.058737446","0.12273684","1.1069162","Follower"],["0.058898717","0.07737231","1.0344048","Follower"],["0.014674484","0.083316706","1.125","Follower"],["0.056113023","0.111489184","1.1252441","Follower"],["0.030584369","0.15690225","1.125173","Follower"],["0.025122592","0.13210374","1.1252372","Follower"],["0.022272712","0.07564597","1.107076","Follower"],["0.065493464","0.18913238","1.1251221","Follower"],["0.07229182","0.19880989","1.1252418","Follower"],["0.027028475","0.104370035","1.1252351","Follower"],["0.07365596","0.09790047","1.1252441","Follower"],["0.07109489","0.15420754","1.1252441","Follower"],["0.017193697","0.20571056","3.4028235e+38","Seed"],["0.055904567","0.15766491","1.1252463","Follower"],["0.021460544","0.058288526","1.125075","Follower"],["0.05036484","0.12545119","1.125075","Follower"],["0.0618841","0.12361565","1.1251221","Follower"],["0.033173304","0.07985711","1.125","Follower"]],"hovertemplate":"Rechit : %{customdata[3]}<br>Energy: %{customdata[0]:.2g} GeV<br>Rho: %{customdata[1]:.2g} GeV<br>Delta: %{customdata[2]:.2g} cm","legendgroup":"rechits","legendgrouptitle":{"text":"Rechits"},"marker":{"color":"#AB63FA","size":[21.773351669311523,21.81244468688965,2.0000057220458984,21.121694564819336,12.469701766967773,9.665133476257324,7.948572158813477,23.325502395629883,24.733489990234375,10.707620620727539,25.0,24.49547004699707,4.25870418548584,21.068632125854492,7.418997287750244,19.58092498779297,22.517343521118164,13.62813663482666],"symbol":"circle"},"mode":"markers","name":"2D cluster nb 80.0","x":[4.027461051940918,4.027461051940918,4.000310897827148,4.000310897827148,4.000310897827148,3.0258326530456543,3.0258326530456543,3.0258326530456543,3.0258326530456543,2.0513453483581543,2.0513453483581543,2.0513453483581543,2.0513453483581543,2.0513453483581543,1.0769801139831543,1.0769801139831543,1.0769801139831543,2.0513453483581543],"y":[-2.5766689777374268,1.924316644668579,0.8902683258056641,-0.23473167419433594,-1.359975814819336,-3.047842025756836,1.452768325805664,-0.7974758148193359,-1.922597885131836,-3.610464096069336,-4.735708236694336,-0.23473167419433594,-1.359975814819336,-2.485229015350342,-5.298208236694336,-0.7974758148193359,-1.922597885131836,0.8902683258056641],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"rechits_chain","line":{"width":1.7704923456661275},"marker":{"angleref":"previous","color":"#AB63FA","size":10,"symbol":"arrow"},"mode":"markers+lines","name":"Rechits chain","showlegend":true,"x":[4.027461051940918,3.0258326530456543],"y":[-2.5766689777374268,-3.047842025756836],"type":"scatter"},{"hoverinfo":"skip","legendgroup":"rechits_chain","line":{"width":2.093978229998494},"marker":{"angleref":"previous","color":"#AB63FA","size":10,"symbol":"arrow"},"mode":"markers+lines","name":"Rechits chain","showlegend":false,"x":[4.027461051940918,4.000310897827148],"y":[1.924316644668579,0.8902683258056641],"type": ...

# %%
plotEvent3D(*eventLayer)
# Out:
# <div>                            <div id="a8ef0840-d429-49d8-83a8-5bfdee6111ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8ef0840-d429-49d8-83a8-5bfdee6111ff")) {                    Plotly.newPlot(                        "a8ef0840-d429-49d8-83a8-5bfdee6111ff",                        [{"customdata":[[285.7215881347656,27.0],[1.017543911933899,4.0]],"hovertemplate":"clus3D_energy=%{customdata[0]:.3g} GeV<br>clus3D_x=%{x}<br>clus3D_y=%{y}<br>clus3D_z=%{z}<br>clus3D_size=%{customdata[1]}<extra></extra>","marker":{"color":["#636EFA","#EF553B"],"size":[60.0,30.0],"symbol":"cross"},"mode":"markers","name":"3D tracksters","x":[2.6851048469543457,2.004483222961426],"y":[-1.152652621269226,-4.832149505615234],"z":[25.790185928344727,52.55896759033203],"type":"scatter3d"},{"customdata":[[0.17536795139312744,0.17536795139312744,1.8340200185775757,"Follower",1,2],[1.624618649482727,6.988164901733398,0.1537390500307083,"Follower",2,8],[5.0269036293029785,13.526448249816895,0.09220127016305923,"Follower",3,17],[8.468027114868164,20.826534271240234,0.18927496671676636,"Follower",4,23],[13.322802543640137,28.92457389831543,0.02406523935496807,"Follower",5,30],[19.082273483276367,37.62825393676758,0.11227239668369293,"Follower",6,30],[22.735939025878906,43.295326232910156,0.05243006348609924,"Follower",7,51],[21.071096420288086,44.52294921875,0.34335222840309143,"Follower",8,46],[22.105138778686523,46.265628814697266,3.4028234663852886e+38,"Seed",9,46],[18.74759864807129,43.7221565246582,0.0875447615981102,"Follower",10,43],[21.265506744384766,44.1136474609375,0.15578719973564148,"Follower",11,52],[17.900049209594727,40.249534606933594,0.09092054516077042,"Follower",12,54],[19.795061111450195,39.74382781982422,0.0333055779337883,"Follower",13,51],[14.621755599975586,34.23046875,0.16414164006710052,"Follower",14,52],[15.212371826171875,32.374420166015625,0.039856817573308945,"Follower",15,57],[11.996557235717773,27.9857177734375,0.0900636836886406,"Follower",16,41],[11.874014854431152,25.055463790893555,0.10571395605802536,"Follower",17,50],[9.622807502746582,21.360797882080078,0.03219957277178764,"Follower",18,41],[8.819792747497559,18.452829360961914,0.05327886715531349,"Follower",19,57],[5.633974075317383,14.281819343566895,0.06134414300322533,"Follower",20,35],[5.153243064880371,11.833477973937988,0.056298691779375076,"Follower",21,41],[3.88458514213562,9.185230255126953,0.16235265135765076,"Follower",22,27],[3.8847813606262207,7.520899295806885,0.10510420054197311,"Follower",23,43],[1.555232286453247,4.530465126037598,0.3053377866744995,"Follower",24,22],[1.456199288368225,3.4583024978637695,0.1637980043888092,"Follower",25,20],[0.4973544180393219,1.9143093824386597,0.07156814634799957,"Follower",26,12],[0.18856234848499298,0.5792731046676636,0.6006969809532166,"Follower",28,5]],"hovertemplate":"2D cluster : %{customdata[3]}<br>Layer : %{customdata[4]}<br>Energy: %{customdata[0]:.2g} GeV<br>Rho: %{customdata[1]:.2g} GeV<br>Delta: %{customdata[2]:.2g} cm<br>Size: %{customdata[5]}","legendgroup":"cluster2D","legendgrouptitle":{"text":"2D clusters"},"marker":{"color":["#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52","#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52","#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52","#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52","#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52","#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E880","#FF97FF","#FECB52","#636EFA","#EF553B","#00CC96","#AB63FA","#FFA15A","#19D3F3","#FF6692","#B6E8 ...

# %%
printCsvRowsFromDf(full_result_df, source="Clus2DLargeDistancePositionToBarycenter", layerColumn="clus2D_layer")
# Out:
# 300;435;2243;23;Clus2DLargeDistancePositionToBarycenter
# 300;435;4627;28;Clus2DLargeDistancePositionToBarycenter
# 300;435;8652;27;Clus2DLargeDistancePositionToBarycenter
# 300;435;479;23;Clus2DLargeDistancePositionToBarycenter
# 20;442;1630;17;Clus2DLargeDistancePositionToBarycenter
# 20;451;9981;17;Clus2DLargeDistancePositionToBarycenter
# 20;451;5763;14;Clus2DLargeDistancePositionToBarycenter
# 50;456;7197;15;Clus2DLargeDistancePositionToBarycenter
# 50;456;9540;16;Clus2DLargeDistancePositionToBarycenter
# 50;456;332;19;Clus2DLargeDistancePositionToBarycenter
# 50;456;1341;15;Clus2DLargeDistancePositionToBarycenter
# 50;457;425;18;Clus2DLargeDistancePositionToBarycenter
# 50;458;2072;17;Clus2DLargeDistancePositionToBarycenter
# 50;460;5106;28;Clus2DLargeDistancePositionToBarycenter
# 50;460;1894;20;Clus2DLargeDistancePositionToBarycenter
# 50;460;2534;17;Clus2DLargeDistancePositionToBarycenter
# 50;461;7046;17;Clus2DLargeDistancePositionToBarycenter
# 50;463;2808;17;Clus2DLargeDistancePositionToBarycenter
# 80;466;631;18;Clus2DLargeDistancePositionToBarycenter
# 80;467;12612;21;Clus2DLargeDistancePositionToBarycenter
# 80;468;2072;16;Clus2DLargeDistancePositionToBarycenter
# 80;468;7514;19;Clus2DLargeDistancePositionToBarycenter
# 80;470;3069;19;Clus2DLargeDistancePositionToBarycenter
# 80;470;4516;17;Clus2DLargeDistancePositionToBarycenter
# 80;471;7361;21;Clus2DLargeDistancePositionToBarycenter
# 80;471;4143;17;Clus2DLargeDistancePositionToBarycenter
# 80;472;3215;15;Clus2DLargeDistancePositionToBarycenter
# 80;474;26;19;Clus2DLargeDistancePositionToBarycenter
# 100;477;8407;26;Clus2DLargeDistancePositionToBarycenter
# 100;479;5493;21;Clus2DLargeDistancePositionToBarycenter
# 100;480;1760;16;Clus2DLargeDistancePositionToBarycenter
# 100;482;3794;21;Clus2DLargeDistancePositionToBarycenter
# 100;482;4833;27;Clus2DLargeDistancePositionToBarycenter
# 100;483;9374;23;Clus2DLargeDistancePositionToBarycenter
# 100;483;346;19;Clus2DLargeDistancePositionToBarycenter
# 100;484;1374;18;Clus2DLargeDistancePositionToBarycenter
# 100;486;3547;19;Clus2DLargeDistancePositionToBarycenter
# 100;486;9520;20;Clus2DLargeDistancePositionToBarycenter
# 100;489;3642;17;Clus2DLargeDistancePositionToBarycenter
# 100;489;8635;22;Clus2DLargeDistancePositionToBarycenter
# 100;490;6956;22;Clus2DLargeDistancePositionToBarycenter
# 100;490;1406;5;Clus2DLargeDistancePositionToBarycenter
# 100;491;6122;7;Clus2DLargeDistancePositionToBarycenter
# 150;493;7541;28;Clus2DLargeDistancePositionToBarycenter
# 150;494;6258;21;Clus2DLargeDistancePositionToBarycenter
# 150;495;2971;19;Clus2DLargeDistancePositionToBarycenter
# 150;495;2190;23;Clus2DLargeDistancePositionToBarycenter
# 150;496;6692;23;Clus2DLargeDistancePositionToBarycenter
# 150;496;13500;21;Clus2DLargeDistancePositionToBarycenter
# 150;496;8128;21;Clus2DLargeDistancePositionToBarycenter
# 150;496;17786;22;Clus2DLargeDistancePositionToBarycenter
# 150;496;18302;21;Clus2DLargeDistancePositionToBarycenter
# 150;496;18369;23;Clus2DLargeDistancePositionToBarycenter
# 150;502;280;15;Clus2DLargeDistancePositionToBarycenter
# 150;503;3075;21;Clus2DLargeDistancePositionToBarycenter
# 150;504;9950;20;Clus2DLargeDistancePositionToBarycenter
# 150;505;8631;21;Clus2DLargeDistancePositionToBarycenter
# 150;506;7385;20;Clus2DLargeDistancePositionToBarycenter
# 150;506;6545;20;Clus2DLargeDistancePositionToBarycenter
# 150;506;8772;20;Clus2DLargeDistancePositionToBarycenter
# 150;508;3034;14;Clus2DLargeDistancePositionToBarycenter
# 150;508;3228;22;Clus2DLargeDistancePositionToBarycenter
# 150;508;9579;20;Clus2DLargeDistancePositionToBarycenter
# 30;596;5753;13;Clus2DLargeDistancePositionToBarycenter
# 30;604;6219;13;Clus2DLargeDistancePositionToBarycenter
# 30;606;517;11;Clus2DLargeDistancePositionToBarycenter
# 50;608;6954;15;Clus2DLargeDistancePositionToBarycenter
# 50;609;2777;17;Clus2DLargeDistancePositionToBarycenter
# 50;610;9966;18;Clus2DLargeDistancePositionToBarycenter
# 50;613;4799;18;Clus2DLargeDistancePositionToBarycenter
# 50;616;11352;19;Clus2DLargeDistancePositionToBarycenter
# 50;619;9605;13;Clus2DLargeDistancePositionToBarycenter
# 120;620;2551;22;Clus2DLargeDistancePositionToBarycenter
# 120;620;2891;20;Clus2DLargeDistancePositionToBarycenter
# 120;620;7777;22;Clus2DLargeDistancePositionToBarycenter
# 120;621;3559;16;Clus2DLargeDistancePositionToBarycenter
# 120;621;8918;21;Clus2DLargeDistancePositionToBarycenter
# 120;622;7105;23;Clus2DLargeDistancePositionToBarycenter
# 120;635;4185;18;Clus2DLargeDistancePositionToBarycenter
# 120;639;6509;12;Clus2DLargeDistancePositionToBarycenter
# 120;640;1525;19;Clus2DLargeDistancePositionToBarycenter
# 120;641;7887;20;Clus2DLargeDistancePositionToBarycenter
# 120;642;9496;21;Clus2DLargeDistancePositionToBarycenter
# 120;643;5596;17;Clus2DLargeDistancePositionToBarycenter
# 250;647;7494;21;Clus2DLargeDistancePositionToBarycenter
# 250;647;640;27;Clus2DLargeDistancePositionToBarycenter
# 250;649;6579;26;Clus2DLargeDistancePositionToBarycenter
# 250;650;2192;27;Clus2DLargeDistancePositionToBarycenter
# 250;650;7391;25;Clus2DLargeDistancePositionToBarycenter
# 250;650;607;23;Clus2DLargeDistancePositionToBarycenter
# 250;652;2216;25;Clus2DLargeDistancePositionToBarycenter
# 250;652;5568;23;Clus2DLargeDistancePositionToBarycenter
# 250;652;8769;24;Clus2DLargeDistancePositionToBarycenter
# 250;652;8983;22;Clus2DLargeDistancePositionToBarycenter
# 250;653;1300;27;Clus2DLargeDistancePositionToBarycenter
# 250;653;1514;21;Clus2DLargeDistancePositionToBarycenter
# 250;654;4931;23;Clus2DLargeDistancePositionToBarycenter
# 250;654;7013;23;Clus2DLargeDistancePositionToBarycenter
# 250;654;3127;22;Clus2DLargeDistancePositionToBarycenter
# 250;654;3262;28;Clus2DLargeDistancePositionToBarycenter
# 80;655;8666;21;Clus2DLargeDistancePositionToBarycenter
# 80;655;5321;16;Clus2DLargeDistancePositionToBarycenter
# 80;656;2504;26;Clus2DLargeDistancePositionToBarycenter
# 80;657;9924;19;Clus2DLargeDistancePositionToBarycenter
# 80;659;2801;16;Clus2DLargeDistancePositionToBarycenter
# 80;659;1167;19;Clus2DLargeDistancePositionToBarycenter
# 80;661;8977;19;Clus2DLargeDistancePositionToBarycenter
# 80;663;6198;17;Clus2DLargeDistancePositionToBarycenter
# 80;663;7661;7;Clus2DLargeDistancePositionToBarycenter
# 80;663;9097;18;Clus2DLargeDistancePositionToBarycenter
# 200;664;3671;20;Clus2DLargeDistancePositionToBarycenter
# 200;665;9781;22;Clus2DLargeDistancePositionToBarycenter
# 200;666;6899;21;Clus2DLargeDistancePositionToBarycenter
# 200;667;3525;20;Clus2DLargeDistancePositionToBarycenter
# 200;671;5845;22;Clus2DLargeDistancePositionToBarycenter
# 200;672;5148;20;Clus2DLargeDistancePositionToBarycenter
# 200;672;664;22;Clus2DLargeDistancePositionToBarycenter
# 200;673;2487;22;Clus2DLargeDistancePositionToBarycenter
# 200;675;6022;21;Clus2DLargeDistancePositionToBarycenter
# 200;675;8183;24;Clus2DLargeDistancePositionToBarycenter
# 200;675;4286;23;Clus2DLargeDistancePositionToBarycenter
# 200;675;1043;27;Clus2DLargeDistancePositionToBarycenter
# 200;676;7398;17;Clus2DLargeDistancePositionToBarycenter
# 200;676;397;28;Clus2DLargeDistancePositionToBarycenter
