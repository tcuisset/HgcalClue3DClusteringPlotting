# %%
import sys
import hist
sys.path.append("..")
from HistogramLib.store import *

# %%
store = HistogramStore("/grid_mnt/data_cms_upgrade/cuisset/testbeam18/clue3d/v4/", "r")

# %%
shelf = store.getShelf(ShelfId(clue_param_name="default", datatype="data"))

# %%
h = shelf["RechitsDelta"]
h
# Out:
# RechitsDelta(
#   IntCategory([20, 50, 80, 100, 120, 150, 200, 250, 300]),
#   Integer(0, 30),
#   Regular(100, 0, 3),
#   storage=Mean()) # Sum: Mean(count=0, value=0, variance=-0) (Mean(count=6.91966e+08, value=0.157232, variance=0.285457) with flow)

# %%
h[{"beamEnergy":hist.loc(100)}]
# Out:
# RechitsDelta(
#   Integer(0, 30),
#   Regular(100, 0, 3),
#   storage=Mean()) # Sum: Mean(count=0, value=0, variance=-0) (Mean(count=7.30584e+07, value=0.1437, variance=0.180772) with flow)
