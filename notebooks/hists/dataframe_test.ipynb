# %% [markdown]
# # Testing of hists/dataframe.py

# %%
# %load_ext autoreload
# %autoreload 2
from functools import partial
import pandas as pd
import numpy as np
import uproot
import awkward as ak
import sys
sys.path.append("../..")
from hists.dataframe import *
from hists.shower_axis import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#input_file = '/grid_mnt/vol_home/llr/cms/cuisset/hgcal/testbeam18/clue3d-dev/src/ClusteringAnalysis/CLUE_clusters_single.root'
input_file = '/data_cms_upgrade/cuisset/testbeam18/clue3d/v30/cmssw/data/CLUE_clusters.root'
#input_file = '/data_cms_upgrade/cuisset/testbeam18/clue3d/v20/cmssw/sim_proton_v7/CLUE_clusters.root'

# %%
for array_i in uproot.iterate(input_file + ":clusters", step_size="10MB", library="ak"):
    series = array_i
    break

# %%
comp = DataframeComputations(series)

# %%
pd.set_option('display.min_rows', 20)
pd.set_option('display.max_rows', 500)

# %%
pca_axis, impact_vector = computeAngleSeries(comp.clusters3D_merged_2D_impact.loc[0, 0], "test")
pca_axis, impact_vector
# Out:
# /tmp/ipykernel_98480/430024364.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   pca_axis, impact_vector = computeAngleSeries(comp.clusters3D_merged_2D_impact.loc[0, 0], "test")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pca_axis, impact_vector = computeAngleSeries(comp.clusters3D_merged_2D_impact.loc[0, 0], "test")
#       2 pca_axis, impact_vector
#
# ValueError: too many values to unpack (expected 2)

# %%
u, v = pca_axis, impact_vector
axis = "y"
angleInPlane(u, v, axis)
# Out:
# -0.007951115004182302

# %%
comp.clusters3D_PCA_dataframe#.clus3D_pca_impact_filterLayerSpan_angle_x.clip(-0.2, 0.2).hist(bins=1000)
# Out:
#                          clus3D_pca_impact_filterLayerSpan_angle
# eventInternal clus3D_id
# 0             0                                         0.028815  \
#               1                                         1.264941
#               2                                         0.228787
#               3                                         0.356813
#               4                                         0.141388
#               5                                         0.269134
# 1             0                                         0.006583
# 2             0                                         0.011363
# 3             0                                         0.004905
# 4             0                                         0.005994
# ...                                                          ...
# 978           1                                         0.122166
# 979           0                                         0.005018
# 980           0                                         0.003745
# 981           0                                         0.006533
# 982           0                                         0.010643
#               1                                         0.598717
# 983           0                                         0.006471
#               1                                         1.249071
# 984           0                                         0.006324
# 985           0                                         0.014402
#
#                          clus3D_pca_impact_filterLayerSpan_angle_x
# eventInternal clus3D_id
# 0             0                                          -0.027696  \
#               1                                          -1.196970
#               2                                           0.075488
#               3                                           0.072477
#               4                                           0.057871
#               5                                          -0.258158
# 1             0                                          -0.000440
# 2             0                                           0.008759
# 3             0                                          -0.001639
# 4             0                                           0.002650
# ...                                                            ...
# 978           1                                          -0.075073
# 979           0                                          -0.003854
# 980           0                                           0.003736
# 981           0                                           0.002170
# 982           0                                          -0.004693
#               1                                           0.048420
# 983           0                                           0.004715
#               1                                          -1.170507
# 984           0                                           0.002464
# 985           0                                          -0.010511
#
#                          clus3D_pca_impact_filterLayerSpan_angle_y
# eventInternal clus3D_id
# 0             0                                          -0.007951  \
#               1                                          -1.082948
#               2                                           0.216769
#               3                                          -0.350524
#               4                                          -0.129287
#               5                                           0.079536
# 1             0                                           0.006554
# 2             0                                           0.007257
# 3             0                                           0.004637
# 4             0                                          -0.005369
# ...                                                            ...
# 978           1                                           0.096740
# 979           0                                          -0.003242
# 980           0                                           0.000348
# 981           0                                           0.006158
# 982           0                                           0.009562
#               1                                           0.597534
# 983           0                                          -0.004448
#               1                                           1.074606
# 984           0                                           0.005830
# 985           0                                          -0.009847
#
#                          clus3D_pca_impact_filterLayerSpan_cleaned_angle
# eventInternal clus3D_id
# 0             0                                                 0.032021  \
#               1                                                 1.144825
#               2                                                 0.228787
#               3                                                 0.356814
#               4                                                 0.244486
#               5                                                 0.306210
# 1             0                                                 0.006302
# 2             0                                                 0.011850
# 3             0                                                 0.004976
# 4             0                                                 0.005851
# ...                                                                  ...
# 978           1                                                 0.134618
# 979           0                                                 0.005060
# 980           0                                                 0.003920
# 981           0                                                 0.006401
# 982           0                                                 0.010699
#               1                                                 0.598717
# 983           0                                                 0.006378
#               1                                                 1.124919
# 984           0                                                 0.006210
# 985           0                                                 0.015555
#
#                          clus3D_pca_impact_filterLayerSpan_cleaned_angle_x
# eventInternal clus3D_id
# 0             0                                                  -0.030719  \
#               1                                                  -1.080774
#               2                                                   0.075488
#               3                                                   0.072477
#               4                                                   0.144133
#               5                                                  -0.273745
# 1             0                                                  -0.000194
# 2             0                                                   0.009160
# 3             0                                                  -0.001391
# 4             0                                                   0.002421
# ...                                                                    ...
# 978           1                                                  -0.091821
# 979           0                                                  -0.003815
# 980           0                                                   0.003938
# 981           0                                                   0.001676
# 982           0                                                  -0.004866
#               1                                                   0.048420
# 983           0                                                   0.004327
#               1                                                  -0.913480
# 984           0                                                   0.002459
# 985           0                                                  -0.010929
#
#                          clus3D_pca_impact_filterLayerSpan_cleaned_angle_y
# eventInternal clus3D_id
# 0             0                                                  -0.009057  \
#               1                                                  -0.859949
#               2                                                   0.216769
#               3                                                  -0.350523
#               4                                                  -0.200193
#               5                                                   0.144251
# 1             0                                                   0.006301
# 2             0                                                   0.007511
# 3             0                                                   0.004790
# 4             0                                                  -0.005305
# ...                                                                    ...
# 978           1                                                   0.098995
# 979           0                                                  -0.003334
# 980           0                                                   0.000334
# 981           0                                                   0.006184
# 982           0                                                   0.009530
#               1                                                   0.597534
# 983           0                                                  -0.004660
#               1                                                   1.023940
# 984           0                                                   0.005707
# 985           0                                                  -0.011072
#
#                          beamEnergy  clus3D_x  clus3D_y   clus3D_z
# eventInternal clus3D_id
# 0             0               300.0  2.650558 -1.848426  21.842970  \
#               1               300.0  5.637034  1.755065  31.647882
#               2               300.0  1.750882  1.526782  34.962189
#               3               300.0  1.384869 -5.632168  38.007500
#               4               300.0  0.224997 -2.668990  40.990173
#               5               300.0  3.704394  1.807746  41.735081
# 1             0               300.0  3.161058 -2.023329  25.210642
# 2             0               300.0  2.840648 -0.835566  27.068089
# 3             0               300.0  2.259072 -1.402807  29.132622
# 4             0               300.0  2.771630 -1.181302  25.748362
# ...                             ...       ...       ...        ...
# 978           1               300.0  6.894516 -2.669625  31.446756
# 979           0               300.0  2.271601 -0.325216  26.654020
# 980           0               300.0  1.666758 -1.670541  27.933380
# 981           0               300.0  1.879907 -1.358368  26.316141
# 982           0               300.0  1.778973 -1.097167  26.664005
#               1               300.0  6.229411  0.065032  30.129627
# 983           0               300.0  2.406450 -0.308072  26.799671
#               1               300.0  4.736692 -1.953305  51.008690
# 984           0               300.0  1.822499 -1.369170  28.476963
# 985           0               300.0  1.945261 -0.590244  26.584818
#
#                          clus3D_energy  clus3D_size
# eventInternal clus3D_id
# 0             0             144.070526           33
#               1               1.374874            8
#               2               6.651038            4
#               3               1.016448            3
#               4               1.290173            6
#               5               6.269024           17
# 1             0             288.672455           36
# 2             0             282.210052           34
# 3             0             281.997314           47
# 4             0             281.543182           38
# ...                                ...          ...
# 978           1               1.517188           12
# 979           0             281.023926           34
# 980           0             279.991913           28
# 981           0             211.368103           40
# 982           0             280.767395           34
#               1               1.324785            7
# 983           0             286.654633           32
#               1               1.075037            4
# 984           0             282.692963           41
# 985           0             275.672943           28
#
# [1244 rows x 12 columns]
