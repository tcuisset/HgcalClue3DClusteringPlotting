# %%
import sys
sys.path.append("../..")
from ntupleReaders.clue_ntuple_reader import ClueNtupleReader
from hists.store import HistogramId
from HistogramLib.histogram import HistogramKind
import hist

# %%
reader = ClueNtupleReader("v41", "cmssw", "sim_proton_v46_patchMIP")

# %%
beamEnergy = 250
h = reader.histStore.get(HistogramId("TrueBeamEnergy", "cmssw", reader.datatype)).getHistogram(HistogramKind.COUNT)[{"beamEnergy":hist.loc(beamEnergy)}]

# %%
h[hist.loc(beamEnergy*0.9):hist.loc(beamEnergy*1.05)].plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f02ebae3a30>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]
