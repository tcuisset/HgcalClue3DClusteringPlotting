# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from jupyter_dash import JupyterDash
import dash
from dash import html

from notebook_visualizer import EventDisplay
from event_visualizer.event_index import EventLoader
from event_visualizer.dash_app.plots import makePlotClue3D, makePlotLayer, makePlotLongitudinalProfile
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
el = EventLoader("/data_cms_upgrade/cuisset/testbeam18/clue3d/v38/cmssw/data/CLUE_clusters.root")

# %%
disp = EventDisplay({"beamEnergy":[50], "event":[3517], "ntupleNumber":[462]}, el, run_server_mode=None)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash app running on http://127.0.0.1:8050/

# %%
disp.loadEvent(0)[0]
# Out:
#            clus2D_x  clus2D_y   clus2D_z  clus2D_energy  clus2D_layer
# clus2D_id
# 0          2.873756 -2.021837  13.877500       0.098565             1  \
# 1          2.618054 -2.169468  14.767500       0.150351             2
# 2          2.977924 -1.961694  16.782499       0.208773             3
# 3          2.691356 -1.971624  17.672501       0.531556             4
# 4          2.982026 -1.953488  19.687500       0.493574             5
# 5          3.137181 -1.925146  20.577499       0.561917             6
# 6          2.447159 -1.955274  22.692499       0.619779             7
# 7          2.942848 -1.878174  23.582500       0.519723             8
# 8          3.192612 -2.361629  25.697500       0.883326             9
# 9          3.477066 -1.588272  26.587500       0.377157            10
# 10         3.142237 -1.885407  28.702499       1.695455            11
# 11         2.855873 -5.427968  29.592501       0.070750            12
# ...

# %%
makePlotLayer(disp.currentEvent, 10)
# Out:
# <div>                            <div id="acbe4eb1-0307-4f0a-952c-2c694a580b46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acbe4eb1-0307-4f0a-952c-2c694a580b46")) {                    Plotly.newPlot(                        "acbe4eb1-0307-4f0a-952c-2c694a580b46",                        [{"customdata":[[0.3771573007106781,2.3374733924865723,0.447660893201828,"Follower"]],"hovertemplate":"2D cluster : %{customdata[3]}<br>Energy: %{customdata[0]:.2g} GeV<br>Rho: %{customdata[1]:.2g} GeV<br>Delta: %{customdata[2]:.2g} cm<br>Size: %{marker.size}","legendgroup":"cluster2D","legendgrouptitle":{"text":"2D clusters"},"marker":{"color":"#00A08B","line":{"color":"black","width":2},"size":34.432860594673876,"symbol":"diamond"},"mode":"markers","name":"Nb 9 
# ...
